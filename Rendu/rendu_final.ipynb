# %%
import gymnasium as gym
import gym_trading_env
import wandb
import pandas as pd
import numpy as np
from wandb.integration.sb3 import WandbCallback
from sb3_contrib import RecurrentPPO
from utils import reward_function_updated

# --- 2. TRAITEMENT (Inchangé) ---
def calculate_indicators(df):
    delta = df['close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    df['feature_rsi'] = 100 - (100 / (1 + rs))
    df['feature_rsi'] = df['feature_rsi'] / 100.0

    exp1 = df['close'].ewm(span=12, adjust=False).mean()
    exp2 = df['close'].ewm(span=26, adjust=False).mean()
    slow_macd = exp1 - exp2
    fast_macd = slow_macd.ewm(span=9, adjust=False).mean()
    df['feature_macd_histogram'] = slow_macd - fast_macd
    df['feature_macd_fast'] = fast_macd
    df['feature_macd_slow'] = slow_macd

    high_low = df['high'] - df['low']
    high_close = np.abs(df['high'] - df['close'].shift())
    low_close = np.abs(df['low'] - df['close'].shift())
    true_range = pd.concat([high_low, high_close, low_close], axis=1).max(axis=1)
    df['feature_atr'] = true_range.rolling(14).mean() / df['close']

    df['feature_return'] = df['close'].pct_change()


    return df.dropna()

def preprocess(df):
    df = df.sort_index().dropna().drop_duplicates()
    return calculate_indicators(df)

# %%
# Liste des différents hyperparamètres à tester
learning_rates = [1e-4, 1e-3] # Taux d'apprentissage (1e-4 et 1e-3)
ent_coefs = [0.01, 0.05] # Coefficients d'entropie pour encourager l'exploration (0.01 et 0.05)
position_ranges = [(-1,1), (-0.5, 0.5), (0,0.8)] # Différentes plages de positions [-1,1], [-0.5,0.5], [0,0.8]
gammas = [0.9, 0.95, 0.99] # Facteurs d'actualisation (0.9, 0.95, 0.99)
gae_lambdas = [0.01, 0.05, 0.1] # Paramètres GAE (0.01, 0.05, 0.1)
batch_sizes = [128, 256] # Tailles de batch (128 et 256)

# Boucle sur toutes les combinaisons d'hyperparamètres
for lr in learning_rates:
    for ent in ent_coefs:
        for pos_range in position_ranges:
            for gamma in gammas:
                for gae_lambda in gae_lambdas:
                    for batch_size in batch_sizes:
                        config = {
                            "policy_type": "MlpLstmPolicy",
                            "total_timesteps": 200_000,    # On allonge encore, l'Alpha est dur à trouver
                            "learning_rate": lr,
                            "ent_coef": ent,
                            "batch_size": batch_size, # Batch plus gros pour lisser le bruit des returns
                            "n_steps": 2048,
                            "position_range": pos_range,
                            "gae_lambda": gae_lambda,
                            "gamma": gamma,
                            "project_name": "RL-Trading-Project",
                            "run_name": f"{lr}_{ent}_{pos_range}_{gamma}_{gae_lambda}_{batch_size}",
                        }
                        run = wandb.init(
                            project=config["project_name"],
                            name=config["run_name"],
                            config=config,
                            sync_tensorboard=True,
                            monitor_gym=True,
                            save_code=True,
                        )

                        env = gym.make(
                            "MultiDatasetTradingEnv",
                            dataset_dir="./data/*.pkl",
                            preprocess=preprocess,
                            portfolio_initial_value=1000,
                            trading_fees=0.1/100,
                            borrow_interest_rate=0.02/100/24,
                            reward_function=reward_function_updated,
                            position_range=config["position_range"]
                        )

                        # Création de la callback Wandb
                        wandb_callback = WandbCallback(
                            gradient_save_freq=100,
                            model_save_path=f"models/{run.id}",
                            verbose=2,
                        )

                        model = RecurrentPPO(
                            config["policy_type"],
                            env,
                            verbose=1,
                            learning_rate=config["learning_rate"],
                            ent_coef=config["ent_coef"],
                            batch_size=config["batch_size"],
                            n_steps=config["n_steps"],
                            tensorboard_log=f"runs/{run.id}",
                            gamma=config["gamma"],
                            gae_lambda=config["gae_lambda"]
                        )

                        print(f"--- Démarrage Alpha Hunter ---")
                        print(f"Objectif : Battre le Buy & Hold (Reward = Return - Market)")
                        print(f"Exploration forcée (Ent_coef={config['ent_coef']})")

                        model.learn(
                            total_timesteps=config["total_timesteps"],
                            callback=wandb_callback
                        )

                        print("Fin de l'apprentissage")

                        model.save("recurrent_ppo_alpha_hunter")

                        obs, info = env.reset()
                        done, truncated = False, False

                        while not (done or truncated):
                            action, _states = model.predict(obs, deterministic=True)
                            obs, reward, done, truncated, info = env.step(action)

                        metrics = env.unwrapped.get_metrics()
                        print("Métriques finales :", metrics)

                        market_return = float(metrics.get("Market Return", "0%").replace('%',''))
                        portfolio_return = float(metrics.get("Portfolio Return", "0%").replace('%', ''))
                        metrics_float = {'Market Return (%): ': market_return, 'Portfolio Return (%): ': portfolio_return}
                        wandb.log(metrics_float)

                        wandb.finish()
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>C:\Users\tomgr\Documents\Cours\RL\RL_Project_Money\wandb\run-20251223_201211-i9bwm7ab</code>
# Syncing run <strong><a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/i9bwm7ab' target="_blank">0.0001_0.01_(-1, 1)_0.9_0.01_128</a></strong> to <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project' target="_blank">https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project</a>
#  View run at <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/i9bwm7ab' target="_blank">https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/i9bwm7ab</a>
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# --- Démarrage Alpha Hunter ---
# Objectif : Battre le Buy & Hold (Reward = Return - Market)
# Exploration forcée (Ent_coef=0.01)
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to runs/i9bwm7ab\RecurrentPPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 1032 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# Market Return : 39.25%   |   Portfolio Return : -94.83%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.48e+03     |
# |    ep_rew_mean          | -245         |
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0012395335 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.023        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0409       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.999        |
# |    value_loss           | 0.181        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.48e+03    |
# |    ep_rew_mean          | -245        |
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007329774 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0929      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0912      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.999       |
# |    value_loss           | 0.202       |
# -----------------------------------------
# Market Return : 26.96%   |   Portfolio Return : -97.93%   |
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.99e+03    |
# |    ep_rew_mean          | -279        |
# | time/                   |             |
# |    fps                  | 504         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009933648 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.08        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0197      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.995       |
# |    value_loss           | 0.0568      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.99e+03    |
# |    ep_rew_mean          | -279        |
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008621756 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0609      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.011      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.99        |
# |    value_loss           | 0.0588      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.99e+03    |
# |    ep_rew_mean          | -279        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016699404 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.0519      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0265     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.981       |
# |    value_loss           | 0.0327      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.99e+03    |
# |    ep_rew_mean          | -279        |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 7           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017088545 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.0646      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0476      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.974       |
# |    value_loss           | 0.0392      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.99e+03    |
# |    ep_rew_mean          | -279        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 8           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009271219 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0423      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0247     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.96        |
# |    value_loss           | 0.0317      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.99e+03   |
# |    ep_rew_mean          | -279       |
# | time/                   |            |
# |    fps                  | 476        |
# |    iterations           | 9          |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01572879 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.0563     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.028     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0174    |
# |    std                  | 0.954      |
# |    value_loss           | 0.0434     |
# ----------------------------------------
# Market Return : 103.41%   |   Portfolio Return : -99.80%   |
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.5e+03    |
# |    ep_rew_mean          | -366       |
# | time/                   |            |
# |    fps                  | 471        |
# |    iterations           | 10         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01427912 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.0925     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00501   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0184    |
# |    std                  | 0.943      |
# |    value_loss           | 0.0256     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 11          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008667963 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.025       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.121       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00817    |
# |    std                  | 0.94        |
# |    value_loss           | 0.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 12          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008672481 |
# |    clip_fraction        | 0.0841      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00387     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0415      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.937       |
# |    value_loss           | 0.228       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 13          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009682663 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0334      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0978      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00819    |
# |    std                  | 0.936       |
# |    value_loss           | 0.428       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 14          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013057423 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.132       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00911    |
# |    std                  | 0.936       |
# |    value_loss           | 0.436       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 15          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006171729 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0644      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00748    |
# |    std                  | 0.937       |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 16          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013258092 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00163     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.937       |
# |    value_loss           | 0.168       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.5e+03    |
# |    ep_rew_mean          | -366       |
# | time/                   |            |
# |    fps                  | 480        |
# |    iterations           | 17         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00634858 |
# |    clip_fraction        | 0.0675     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.229      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0761     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00784   |
# |    std                  | 0.936      |
# |    value_loss           | 0.18       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 18          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016194444 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0055     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.934       |
# |    value_loss           | 0.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.5e+03      |
# |    ep_rew_mean          | -366         |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 19           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0050375294 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.102        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00724     |
# |    std                  | 0.935        |
# |    value_loss           | 0.245        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 20          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009183681 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0364      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00856    |
# |    std                  | 0.932       |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 21          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010504905 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.000238    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00942    |
# |    std                  | 0.931       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.5e+03      |
# |    ep_rew_mean          | -366         |
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 22           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0116519835 |
# |    clip_fraction        | 0.0979       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0397       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00676     |
# |    std                  | 0.931        |
# |    value_loss           | 0.103        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 23          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010220205 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00923     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.927       |
# |    value_loss           | 0.0594      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 24          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007877467 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0195      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.915       |
# |    value_loss           | 0.022       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.5e+03      |
# |    ep_rew_mean          | -366         |
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 25           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0072795367 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00521     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00904     |
# |    std                  | 0.911        |
# |    value_loss           | 0.104        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.5e+03    |
# |    ep_rew_mean          | -366       |
# | time/                   |            |
# |    fps                  | 492        |
# |    iterations           | 26         |
# |    time_elapsed         | 108        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00984778 |
# |    clip_fraction        | 0.0949     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.131      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.239      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0122    |
# |    std                  | 0.909      |
# |    value_loss           | 0.25       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.5e+03    |
# |    ep_rew_mean          | -366       |
# | time/                   |            |
# |    fps                  | 494        |
# |    iterations           | 27         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01677512 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.227      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0452     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0113    |
# |    std                  | 0.906      |
# |    value_loss           | 0.116      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 494         |
# |    iterations           | 28          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009178662 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0569      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00994    |
# |    std                  | 0.903       |
# |    value_loss           | 0.131       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 29          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013590486 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00235     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00297    |
# |    std                  | 0.905       |
# |    value_loss           | 0.191       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.5e+03      |
# |    ep_rew_mean          | -366         |
# | time/                   |              |
# |    fps                  | 497          |
# |    iterations           | 30           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0077212416 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00936      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00455     |
# |    std                  | 0.905        |
# |    value_loss           | 0.145        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 31          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.006768859 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0267      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00373    |
# |    std                  | 0.902       |
# |    value_loss           | 0.143       |
# -----------------------------------------
# Market Return : 914.64%   |   Portfolio Return : -99.86%   |
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+04    |
# |    ep_rew_mean          | -447        |
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 32          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010594195 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0187      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0063     |
# |    std                  | 0.901       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+04     |
# |    ep_rew_mean          | -447         |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 33           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0056454036 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.338        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0412      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.893        |
# |    value_loss           | 0.00794      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+04     |
# |    ep_rew_mean          | -447         |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 34           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0030734544 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.327        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0272      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00878     |
# |    std                  | 0.885        |
# |    value_loss           | 0.00219      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+04    |
# |    ep_rew_mean          | -447        |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 35          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005528033 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0206     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00778    |
# |    std                  | 0.877       |
# |    value_loss           | 0.000488    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+04     |
# |    ep_rew_mean          | -447         |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 36           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0020198193 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0129      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00275     |
# |    std                  | 0.875        |
# |    value_loss           | 0.00272      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+04     |
# |    ep_rew_mean          | -447         |
# | time/                   |              |
# |    fps                  | 522          |
# |    iterations           | 37           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0060024615 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.0846       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00583      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.873        |
# |    value_loss           | 0.00365      |
# ------------------------------------------
# Market Return :  5.54%   |   Portfolio Return : -9.16%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.52e+04     |
# |    ep_rew_mean          | -360         |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 38           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0014592782 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0244      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.862        |
# |    value_loss           | 0.000362     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 39          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.017752133 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0185      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00806    |
# |    std                  | 0.862       |
# |    value_loss           | 0.0648      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 40          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.031385906 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.104       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.862       |
# |    value_loss           | 0.207       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 531         |
# |    iterations           | 41          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028336728 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00646    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.862       |
# |    value_loss           | 0.253       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 42          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.024464456 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0989      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.861       |
# |    value_loss           | 0.222       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.52e+04   |
# |    ep_rew_mean          | -360       |
# | time/                   |            |
# |    fps                  | 536        |
# |    iterations           | 43         |
# |    time_elapsed         | 164        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.02316176 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.411      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0355     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0204    |
# |    std                  | 0.861      |
# |    value_loss           | 0.123      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 44          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.027111743 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0326      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.861       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.52e+04  |
# |    ep_rew_mean          | -360      |
# | time/                   |           |
# |    fps                  | 536       |
# |    iterations           | 45        |
# |    time_elapsed         | 171       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0220925 |
# |    clip_fraction        | 0.156     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.27     |
# |    explained_variance   | 0.236     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 0.0107    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0239   |
# |    std                  | 0.861     |
# |    value_loss           | 0.144     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 46          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.030180203 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0205     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.861       |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 47          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018770214 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0243     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.86        |
# |    value_loss           | 0.158       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 48          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019922756 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00633    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.861       |
# |    value_loss           | 0.0971      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 49          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.023944147 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00818     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.861       |
# |    value_loss           | 0.0607      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 50          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.017672604 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0126     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.859       |
# |    value_loss           | 0.0983      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 51          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.026125785 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.023      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.857       |
# ...
# | train/                  |             |
# |    approx_kl            | 0.008574145 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0292     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00663    |
# |    std                  | 0.791       |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+04     |
# |    ep_rew_mean          | -322         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 87           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0076617943 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00847     |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00412     |
# |    std                  | 0.789        |
# |    value_loss           | 0.00728      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+04    |
# |    ep_rew_mean          | -322        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 88          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.009267345 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0042     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00569    |
# |    std                  | 0.785       |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+04     |
# |    ep_rew_mean          | -322         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 89           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0104930075 |
# |    clip_fraction        | 0.0797       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00877     |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00621     |
# |    std                  | 0.78         |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# Market Return : 103.41%   |   Portfolio Return : 28.22%   |
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1.84e+04 |
# |    ep_rew_mean          | -296     |
# | time/                   |          |
# |    fps                  | 570      |
# |    iterations           | 90       |
# |    time_elapsed         | 323      |
# |    total_timesteps      | 184320   |
# | train/                  |          |
# |    approx_kl            | 0.012085 |
# |    clip_fraction        | 0.0727   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.17    |
# |    explained_variance   | 0.218    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 0.0267   |
# |    n_updates            | 890      |
# |    policy_gradient_loss | -0.00617 |
# |    std                  | 0.776    |
# |    value_loss           | 0.039    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+04    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 91          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.011416237 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.315       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0568      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00913    |
# |    std                  | 0.773       |
# |    value_loss           | 0.0433      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+04    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 92          |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.011779524 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0276      |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.772       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+04    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 93          |
# |    time_elapsed         | 608         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.026532069 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0661      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.772       |
# |    value_loss           | 0.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+04    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 94          |
# |    time_elapsed         | 612         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.019294687 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.1         |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.772       |
# |    value_loss           | 0.337       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.84e+04   |
# |    ep_rew_mean          | -296       |
# | time/                   |            |
# |    fps                  | 315        |
# |    iterations           | 95         |
# |    time_elapsed         | 617        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.02876293 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.176      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0474     |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0162    |
# |    std                  | 0.772      |
# |    value_loss           | 0.358      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+04    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 96          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.019115062 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0282      |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.772       |
# |    value_loss           | 0.264       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+04    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 97          |
# |    time_elapsed         | 625         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.021059066 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0414      |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.772       |
# |    value_loss           | 0.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+04    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 98          |
# |    time_elapsed         | 630         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.018941006 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.2         |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.772       |
# |    value_loss           | 0.242       |
# -----------------------------------------
# wandb: WARNING Linked 1 file into the W&B run directory (hardlinks); call wandb.save again to sync new files.
# Fin de l'apprentissage
# Market Return : 39.25%   |   Portfolio Return : 39.25%   |
# Métriques finales : {'Market Return': '39.25%', 'Portfolio Return': '39.25%'}
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Market Return (%): </td><td>▁</td></tr><tr><td>Portfolio Return (%): </td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇█████</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▇▇▇▇▇▇▇▇███▇▇▇▇▇</td></tr><tr><td>rollout/ep_rew_mean</td><td>██████████▁▄▅▅▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇█████</td></tr><tr><td>time/fps</td><td>▇▇██████████████████████████▇▇▇▇▇▇▇▇▇▁▁▁</td></tr><tr><td>train/approx_kl</td><td>▁▂▁▂▂▂▂▃▂▃▂▃▃▃▃▂▂▂▂▂▂▃▃▂▂▂▁▁▁▂▁█▂▂▂▂▃▃▄▄</td></tr><tr><td>train/clip_fraction</td><td>▁▂▃▄█▇█▇▃▃▂▅▄▄▄▅▃▄▄▅▄▄▁▃▂▂▂▂▁▂▂▆▄▅▄▄▅█▇▇</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▂▂▂▂▂▂▂▃▅▅▆▆▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Market Return (%): </td><td>39.25</td></tr><tr><td>Portfolio Return (%): </td><td>39.25</td></tr><tr><td>global_step</td><td>200704</td></tr><tr><td>rollout/ep_len_mean</td><td>18396.1</td></tr><tr><td>rollout/ep_rew_mean</td><td>-295.63608</td></tr><tr><td>time/fps</td><td>318</td></tr><tr><td>train/approx_kl</td><td>0.01894</td></tr><tr><td>train/clip_fraction</td><td>0.13569</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-1.15999</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">0.0001_0.01_(-1, 1)_0.9_0.05_128</strong> at: <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/wtj5grnr' target="_blank">https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/wtj5grnr</a><br> View project at: <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project' target="_blank">https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project</a><br>Synced 7 W&B file(s), 0 media file(s), 3 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20251223_202349-wtj5grnr\logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>C:\Users\tomgr\Documents\Cours\RL\RL_Project_Money\wandb\run-20251223_203432-huxukg7b</code>
# Syncing run <strong><a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/huxukg7b' target="_blank">0.0001_0.01_(-1, 1)_0.9_0.05_256</a></strong> to <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project' target="_blank">https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project</a>
#  View run at <a href='https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/huxukg7b' target="_blank">https://wandb.ai/thomas-derville-cpe-lyon/RL-Trading-Project/runs/huxukg7b</a>
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# --- Démarrage Alpha Hunter ---
# Objectif : Battre le Buy & Hold (Reward = Return - Market)
# Exploration forcée (Ent_coef=0.01)
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to runs/huxukg7b\RecurrentPPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 654  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
